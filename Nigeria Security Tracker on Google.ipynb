# %%
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd

# %%
# kongaaURL = "https://www.konga.com/"
# headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'}

# %%
# k = requests.get('https://www.konga.com/search?search=iphone', {'headers':headers}).text
# soup=BeautifulSoup(k,'html.parser')
# productlist = soup.find_all("li",{"class":"_22339_3gQb9"})
# # lis = soup.find_all("article")
# productlist
# # lis
# Out:
# []

# %%
# products = soup.find_all("div", {"class": "af885_1iPzH"})
# prices = soup.find_all("div", {"class": "_4e81a_39Ehs"})
# prices
# Out:
# []

# %% [markdown]
# # Nigeria Security Tracker Tracks Violence in the Country.

# %%
text= "Nigeria Security Tracker"
url = 'https://google.com/search?q=' + text
  
# Fetch the URL data using requests.get(url),
# store it in a variable, request_result.
request_result=requests.get( url )
  
# Creating soup from the fetched request
soup = bs4.BeautifulSoup(request_result.text,"html.parser")
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-NG"><head><meta charset="utf-8"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><title>Nigeria Security Tracker - Google Search</title><script nonce="XhcdTntYe+iVoeSP30CFTg==">(function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){
# ...

# %%
# soup.find.all( div ) to grab 
# all major headings of our search result,
heading_object=soup.find_all( 'div' )
  
# Iterate through the object 
# and print it as a string.
for info in heading_object:
    print(info.getText())
    print("------")
# Out:
# Google
# ------
# Google×
# ------
# ×
# ------
# ×
# ------
# ×
# ------
#
# ------
# Please click here if you are not redirected within a few seconds.
# ------
# ...

# %%
url2022 = 'https://google.com/search?q=' + text + '2021'
request_result=requests.get( url2022 )
  
# Creating soup from the fetched request
soup22 = bs4.BeautifulSoup(request_result.text,"html.parser")
soup22
# Out:
# <!DOCTYPE html>
# <html lang="en-NG"><head><meta charset="utf-8"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><title>Nigeria Security Tracker2021 - Google Search</title><script nonce="Cs+I169weCetehoNQU5a5Q==">(function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){
# ...

# %%
heading_object22=soup22.find_all( 'div' )
  
# Iterate through the object 
# and print it as a string.
for info in heading_object:
    print(info.getText())
    print("------")
# Out:
# Google
# ------
# Google×
# ------
# ×
# ------
# ×
# ------
# ×
# ------
#
# ------
# Please click here if you are not redirected within a few seconds.
# ------
# ...
