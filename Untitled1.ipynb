# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re
import time
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
from time import sleep
from random import randint

# %%
# Empty lists where data will be stored
bookTitles = []
authors = []
years = []
book_types = []
prices = []
ratings = []
displayed_total = []

# %%
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

# %%
# This changes the parameter of the URL, the step parameter shows they are 16 per page
pages = np.arange(1, 625, 16)

# %%
for page in pages:
    page = requests.get("https://www.amazon.com/s?k=amazon+shopping+online&i=stripbooks&s=salesrank" + str(page) + '&Adv-Srch-Books-Submit.x=39&Adv-Srch-Books-Submit.y=11&unfiltered=1&ref=sr_pg_'+str(page), headers=headers)

    soup = BeautifulSoup(page.text, 'html.parser')
  
    books = soup.find_all('div', class_='s-result-item s-asin sg-col-0-of-12 sg-col-16-of-20 sg-col s-widget-spacing-small sg-col-12-of-16')
#     books = soup.find_all("div",{"class":"a-section"})
#     books = soup.find_all("div",{"class":"s-card-container s-overflow-hidden aok-relative s-include-content-margin s-latency-cf-section s-card-border"})

#     This will control the crawl rate on the website
    sleep(randint(2,10))
# Out:
# ---------------------------------------------------------------------------
# SSLEOFError                               Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# ...

# %%
books
# Out:
# []

# %%
for d in books:
#     title = d.h2.a.text
    title = d.find('span', attrs={'class':'a-size-medium a-color-base a-text-normal'}).text
    bookTitles.append(title)
    
    author = d.find('a', attrs={'class':'a-size-base a-link-normal s-underline-text s-underline-link-text s-link-style'})
    authors.append(author)
    
    year = d.find('span', attrs={'class':'a-size-base a-color-secondary a-text-normal'}).text
    years.append(year)
    
    bt = d.find('a', attrs={'class':'a-size-base a-link-normal s-underline-text s-underline-link-text s-link-style a-text-bold'}).text
#     book_type = bt[0].text
    book_types.append(bt)
    
    p = d.find('span', attrs={'class':'a-offscreen'}).text
#     price = p[0].text
    prices.append(p)
    
    rating = d.find('span', attrs={'class':'a-icon-alt'}).text
    ratings.append(rating)

# %%
# prices, book_types

# %%
bookTitles
# Out:
# ['It Ends with Us: A Novel (1)',
#  'School Zone - Big Preschool Workbook - 320 Pages, Ages 3 to 5, Colors, Shapes, Numbers, Early Math, Alphabet, Pre-Writing, Phonics, Following Directions, and More (School Zone Big Workbook Series)',
#  'The Storyteller: Tales of Life and Music',
#  'How to Talk to Your Cat About Gun Safety: And Abstinence, Drugs, Satanism, and Other Dangers That Threaten Their Nine Lives',
#  'Happy Easter, Little Critter (Little Critter) (Look-Look)',
#  'The Berenstain Bears and the Easter Story: Stickers Included! (Berenstain Bears/Living Lights: A Faith Story)',
#  'Wish',
#  'Baby Touch and Feel: Bunny',
#  'The Complete Ketogenic Diet for Beginners: Your Essential Guide to Living the Keto Lifestyle',
#  'StrengthsFinder 2.0',
#  'Publication Manual of the American Psychological Association: 7th Edition, Official, 2020 Copyright',
#  'Dead End Girl (Violet Darger FBI Mystery Thriller Book 1)',
# ...

# %%
data = pd.DataFrame({
'titles': bookTitles,
'year': years,
'ratings': ratings,
'bookTypes': book_types,
'prices': prices
})
data.dtypes, data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11100/2036295765.py in <module>
# ----> 1 data = pd.DataFrame({
#       2 'titles': bookTitles,
#       3 'year': years,
#       4 'ratings': ratings,
#       5 'bookTypes': book_types,
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %%
data.describe()
# Out:
#                               titles         year             ratings  \
# count                             48           48                  48
# unique                            16           16                   5
# top     It Ends with Us: A Novel (1)  Aug 2, 2016  4.8 out of 5 stars
# freq                               3            3                  18
#
#         bookTypes  prices
# count          48      48
# unique          4      19
# top     Paperback  $11.17
# freq           33       3

# %%
no_pages = 625

def get_data(pageNo):  
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    r = requests.get('https://www.amazon.com/s?k=amazon+shopping+online&i=stripbooks&s=salesrank'+str(pageNo)+'&Adv-Srch-Books-Submit.x=39&Adv-Srch-Books-Submit.y=11&unfiltered=1&ref=sr_pg_'+str(pageNo), headers=headers)#, proxies=proxies)
    content = r.content
    soup = BeautifulSoup(content).text
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-us"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-na.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...
